# %% [markdown]
# # Computer Vision III: Detection, Segmentation and Tracking (CV3DST) GNN Exercise
#
# In this exercise, we will first develop an extension of the ReID-based tracker we created in the previous exercise that will make it more robust to occlusions by allowing it to recover from missed detections.
#
# We will then implement a Message Passing Network from scratch, and we will use to build a model that will learn to combine position information and reid features to directly predict associations between past tracks and detections. We will use this model to create robust tracker.
#
# Your tasks are the following:
# - Adapt the track management scheme of our ReIDTracker allow it to recover from missed detections.
# - Implement a Message Passing Network from scratch to operate on bipartite graphs
# - Implement the pairwise feature  computation to obtain features for our Message Passing Network
# - Train the Message Passing Network and improve your tracker's IDF1 score
#
#
# ## Setup
#
# ### Download and extract project data to your Google Drive
#
# 1.   **Required**: Please follow all instructions of exercise 0 before running this notebook.
# 2.   Save this notebook to your Google Drive by clicking `Save a copy in Drive` from the `File` menu.
# 3.   Download [this](https://vision.in.tum.de/webshare/u/brasoand/cv3dst/cv3dst_gnn_exercise.zip) zip file to your desktop, extract it and upload it into the `Colab Notebooks` folder in your Google Drive.

# %% [markdown]
# #### Connect the notebook to your Google Drive

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
root_dir = "gdrive/My Drive/Colab Notebooks/cv3dst_exercise/"
gnn_root_dir = "gdrive/My Drive/Colab Notebooks/cv3dst_gnn_exercise/"

# %% [markdown]
# The `root_dir` path points to the directory and the content in your Google Drive.

# %%
# !ls "gdrive/My Drive/Colab Notebooks/cv3dst_gnn_exercise/data"
# Out:
# preprocessed_data_test_2.pth  preprocessed_data_train_2.pth

# %% [markdown]
# #### Install and import Python libraries

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# !pip install tqdm lap
# !pip install https://github.com/timmeinhardt/py-motmetrics/archive/fix_pandas_deprecating_warnings.zip
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.62.3)
# Collecting lap
#   Downloading lap-0.4.0.tar.gz (1.5 MB)
#      |████████████████████████████████| 1.5 MB 7.5 MB/s
# Building wheels for collected packages: lap
#   Building wheel for lap (setup.py) ... done
#   Created wheel for lap: filename=lap-0.4.0-cp37-cp37m-linux_x86_64.whl size=1590197 sha256=719358f04e2a110dfc72b4cc1d13add4d7da0ff6018c139aed5ef46a9d72f920
#   Stored in directory: /root/.cache/pip/wheels/b1/0b/e3/ef9daf1b5547b56389e42c80c3100f1e6479bf5fd00fd9d6ba
# Successfully built lap
# Installing collected packages: lap
# Successfully installed lap-0.4.0
# Collecting https://github.com/timmeinhardt/py-motmetrics/archive/fix_pandas_deprecating_warnings.zip
#   Downloading https://github.com/timmeinhardt/py-motmetrics/archive/fix_pandas_deprecating_warnings.zip
#      / 148 kB 2.9 MB/s
# Requirement already satisfied: numpy>=1.12.1 in /usr/local/lib/python3.7/dist-packages (from motmetrics==1.1.3) (1.19.5)
# Requirement already satisfied: pandas>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from motmetrics==1.1.3) (1.1.5)
# Requirement already satisfied: scipy>=0.19.0 in /usr/local/lib/python3.7/dist-packages (from motmetrics==1.1.3) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.1->motmetrics==1.1.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.1->motmetrics==1.1.3) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.1->motmetrics==1.1.3) (1.15.0)
# Building wheels for collected packages: motmetrics
#   Building wheel for motmetrics (setup.py) ... done
#   Created wheel for motmetrics: filename=motmetrics-1.1.3-py3-none-any.whl size=134199 sha256=1dd4b1fc3ac5cdfc8f0af393ba4046ff567ff042687e2b38963fae2e6653d673
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0tpanu2b/wheels/39/60/bf/90b1b02ff42db1bf7f2d2fa3eef2fe8bc46061182cf4ce7b37
# Successfully built motmetrics
# Installing collected packages: motmetrics
# Successfully installed motmetrics-1.1.3

# %%
import os
import sys
sys.path.append(os.path.join(gnn_root_dir, 'src'))


import matplotlib.pyplot as plt
import numpy as np
import time
from tqdm.autonotebook import tqdm

import torch
from torch.utils.data import DataLoader

from tracker.data_track import MOT16Sequences
from tracker.tracker import Tracker, ReIDTracker
from tracker.utils import run_tracker, cosine_distance
from scipy.optimize import linear_sum_assignment as linear_assignment
import os.path as osp

import motmetrics as mm
mm.lap.default_solver = 'lap'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   if __name__ == '__main__':

# %%
# !ls "gdrive/My Drive/Colab Notebooks/cv3dst_exercise/data/MOT16/train"
# !ls "gdrive/My Drive/Colab Notebooks/cv3dst_exercise/data/MOT16/test"
# Out:
# MOT16-02  MOT16-04  MOT16-05  MOT16-09	MOT16-10  MOT16-11  MOT16-13
# MOT16-01       MOT16-03_2021  MOT16-08	     MOT16-12_2021
# MOT16-01_2021  MOT16-06_2021  MOT16-08_2021  MOT16-14_2021
# MOT16-03       MOT16-07_2021  MOT16-12

# %% [markdown]
# ## Speed-Ups
# In order to speed up training and inference runtimes, in this exercise we will be working with pre-computed detections and ReID embeddings. We ran the object detector we provided in Exercise 0 and applied to all frames. We also computed reid embeddings for all boxes in every frame of the dataset so that they don't need to be computed every time you run your tracker. This yields over 10x speed improvements. You will not have to work directly with the resulting files, as we have internally adapted the boilerplate code to work with them.

# %%
train_db = torch.load(osp.join(gnn_root_dir, 'data/preprocessed_data_train_2.pth'))

# %% [markdown]
# ## Exercise Part 0 - Assignment's 1 ReIDHungarianTracker
#
# We start by providing a sample solution of the ``ReIDTracker`` from Exercise 1.
# It will serve as our baseline.
#
#
# Recall that this tracker works by performing frame-to-frame bipartite matching between newly detected boxes and past tracks based on ReID distance. Whenever a past track cannot be matched, its killed. And whenever, a newly detected box cannot be match, it starts a new trajectory.
#
# **NOTE**: We have modified the ``compute_distance`` function in ``data_association`` from last week to include a thresshold on ReID distance (if ReID distance >0.1, matching is not possible). This is important to prevent our tracker from reusing tracks for very dissimilar objects.

# %%
_UNMATCHED_COST=255
class ReIDHungarianTracker(ReIDTracker):
    def data_association(self, boxes, scores, pred_features):  
        """Refactored from previous implementation to split it onto distance computation and track management"""
        if self.tracks:
            track_boxes = torch.stack([t.box for t in self.tracks], axis=0)
            track_features = torch.stack([t.get_feature() for t in self.tracks], axis=0)
            
            distance = self.compute_distance_matrix(track_features, pred_features,
                                                    track_boxes, boxes, metric_fn=cosine_distance)

            # Perform Hungarian matching.
            row_idx, col_idx = linear_assignment(distance)  # 和上个exercise一样，这一句实现匈牙利分配算法，将已有的track_boxes 和 预测的boxes 进行匹配，使总的loss最小。 
            # row_idx是一个一维数组，存着已有Track的被匹配的在distance数组里的行数。col_idx和其长度相等，存着对应的被匹配的预测的boxes在distance数组里的行数          
            self.update_tracks(row_idx, col_idx,distance, boxes, scores, pred_features)

            
        else:
            # No tracks exist.
            self.add(boxes, scores, pred_features)
        
    def update_tracks(self, row_idx, col_idx, distance, boxes, scores, pred_features):
        """Updates existing tracks and removes unmatched tracks.
           Reminder: If the costs are equal to _UNMATCHED_COST, it's not a 
           match. 
        """
        track_ids = [t.id for t in self.tracks]

        unmatched_track_ids = []
        seen_track_ids = []
        seen_box_idx = []
        for track_idx, box_idx in zip(row_idx, col_idx):
            costs = distance[track_idx, box_idx] 
            internal_track_id = track_ids[track_idx]  # 这里可以看出，row_idx里面的element不直接是track_ids，而是track_ids里面的index
            seen_track_ids.append(internal_track_id)  # 如果已有track_box里面的id在row_idx里面，那么就是相当于被seen了，但其实不一定是匹配上了，还得看cost是不是255.见下
            if costs == _UNMATCHED_COST:
                unmatched_track_ids.append(internal_track_id)
            else:
                self.tracks[track_idx].box = boxes[box_idx]
                self.tracks[track_idx].add_feature(pred_features[box_idx])
                seen_box_idx.append(box_idx)

        unseen_track_ids = set(track_ids) - set(seen_track_ids)  # set() 函数创建一个无序不重复元素集，可进行关系测试，删除重复数据，还可以计算交集、差集、并集等。这里是作差集
        unmatched_track_ids.extend(list(unseen_track_ids))  # append函数直接将object整体当作一个元素追加到列表中，而extend函数则是将可迭代对象中的元素逐个追加到列表中。
        self.tracks = [t for t in self.tracks
                       if t.id not in unmatched_track_ids]


        # Add new tracks.
        new_boxes_idx = set(range(len(boxes))) - set(seen_box_idx)
        new_boxes = [boxes[i] for i in new_boxes_idx]
        new_scores = [scores[i] for i in new_boxes_idx]
        new_features = [pred_features[i] for i in new_boxes_idx]
        self.add(new_boxes, new_scores, new_features)

# %%
val_sequences = MOT16Sequences('MOT16-reid', root_dir = osp.join(root_dir, 'data/MOT16'), vis_threshold=0.)

# %%
tracker = ReIDHungarianTracker(None)
run_tracker(val_sequences, db=train_db, tracker=tracker, output_dir=None)
# Out:
# Tracking: MOT16-02
# Tracks found: 314
# Runtime for MOT16-02: 6.4 s.
# Tracking: MOT16-05
# Tracks found: 295
# Runtime for MOT16-05: 1.7 s.
# Tracking: MOT16-09
# Tracks found: 87
# Runtime for MOT16-09: 1.3 s.
# Tracking: MOT16-11
# Tracks found: 187
# Runtime for MOT16-11: 2.9 s.
# Runtime for all sequences: 12.2 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT  MT  PT ML   FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 41.6% 59.1% 32.1% 52.2% 96.1%  62  11  39 12  390  8873 203  216 49.1% 0.096
# MOT16-05 57.9% 68.5% 50.1% 68.8% 94.0% 133  56  65 12  305  2156 176  146 61.9% 0.142
# MOT16-09 52.2% 64.6% 43.8% 66.3% 97.7%  26  13  12  1   82  1793  72   79 63.4% 0.083
# MOT16-11 63.4% 69.9% 58.0% 80.2% 96.6%  75  44  24  7  266  1871  88   90 76.4% 0.083
# OVERALL  51.6% 64.8% 42.8% 63.5% 96.1% 296 124 140 32 1043 14693 539  531 59.6% 0.099
#               idf1       idp       idr  ...  num_fragmentations      mota      motp
# MOT16-02  0.416193  0.591008  0.321188  ...                 216  0.490555  0.095583
# MOT16-05  0.578820  0.684564  0.501373  ...                 146  0.618765  0.141840
# MOT16-09  0.522430  0.646099  0.438498  ...                  79  0.634366  0.082864
# MOT16-11  0.634042  0.699017  0.580119  ...                  90  0.764201  0.082746
# OVERALL   0.515792  0.648089  0.428351  ...                 531  0.595743  0.098641
#
# [5 rows x 15 columns]

# %% [markdown]
# ## Exercise Part I - Long-Term ReID Tracker

# %% [markdown]
# The tracker above has an obvious limitation: whenever a track cannot be matched with the detections of a given frame the track will be killed. This means that if our detector misses an object in a single frame (due to e.g. occlusion), we will not be able to recover that track, and we will start a new one. 上述方法的弊端：某个tracks一旦在某个frame中没被匹配上，那么就直接删除了，这样不好。
#
# To fix this issue, we would like to allow our tracker to maintain tracks that are not matched during data association. We will refer to these tracks as **inactive**. During data association, we will try to match the detected boxes for the current frame to both tracks that are active (i.e. tracks that we were able to match in the previous frame) as well as those that are inactive. Therefore, if a detector misses an object in a frame and the object reappears after a few frames, we will still be able to match it to its corresponding track, instead of creating a new one. 对于track引入一个inactive属性，其值为该track没有被match的frames数，若该值超过了设置的patient，则kill掉这个tracks。一旦在容忍度之内又重新匹配上了，这个inactive的值会被重新初始化为0
#
# In order to adapt our tracker to have this behavior, we will use the `inactive` attribute from the `track` class (see `tracker/tracker.py`. This attribute will be assigned an integer indicating for how many frames a track has remained unmatched. Whenever we are able to match the track `t`, we will set `t.inactive=0` and, naturally, when tracks are initialized, the class constructor sets `inactive=0`.
#
# Your job is to maintain the `inactive` attribute of all tracks being kept by tracker so that its value represents the number of frames for which the track has been unmatched. Additionally, we introduce a `patience` parameter. Whenever a track has been inactive for more than `inactive` frames. it will need to be killed.

# %%
class LongTermReIDHungarianTracker(ReIDHungarianTracker):
    def __init__(self, patience, *args, **kwargs):
        """ Add a patience parameter"""
        self.patience=patience
        super().__init__(*args, **kwargs)

    def update_results(self):
        """Only store boxes for tracks that are active"""
        for t in self.tracks:
            if t.id not in self.results.keys():
                self.results[t.id] = {}
            if t.inactive == 0: # Only change
                self.results[t.id][self.im_index] = np.concatenate([t.box.cpu().numpy(), np.array([t.score])])

        self.im_index += 1        
        
    def update_tracks(self, row_idx, col_idx, distance, boxes, scores, pred_features):
        track_ids = [t.id for t in self.tracks]  # 这个list里面存着所有已有tracks的id

        unmatched_track_ids = []
        seen_track_ids = []
        seen_box_idx = []
        for track_idx, box_idx in zip(row_idx, col_idx):
            costs = distance[track_idx, box_idx] 
            internal_track_id = track_ids[track_idx]
            seen_track_ids.append(internal_track_id)  # 被看见的 不等于 被匹配上，因为可能cost=255
            if costs == _UNMATCHED_COST:
                unmatched_track_ids.append(internal_track_id)  # distance等于255，就说明没有匹配上。这个list里面存着未匹配上的tracks的id

            else: # 否则就算是匹配上了
                self.tracks[track_idx].box = boxes[box_idx]
                self.tracks[track_idx].add_feature(pred_features[box_idx])
                
                # Note: the track is matched, therefore, inactive is set to 0
                self.tracks[track_idx].inactive=0  # 匹配上的话，当前track,即 self.tracks[track_idx] 的inactive属性重置为0
                seen_box_idx.append(box_idx)  # seen_box_idx里面存着的是，预测的tracks被匹配上的box_idx
                

        unseen_track_ids = set(track_ids) - set(seen_track_ids)  # unseen_track_ids是原本已有的tracks 减去 被看见的tracks
        unmatched_track_ids.extend(list(unseen_track_ids))  # 未被匹配上的tracks 包括两种情况：一种是未被看见，一种是被看见了 但未被匹配上（cost=255）
        ##################
        ### TODO starts
        ##################
        
        # Update the `inactive` attribute for those tracks that have been 
        # not been matched. kill those for which the inactive parameter 
        # is > self.patience

        killed_track_ids = []
        for unmatched_track_id in unmatched_track_ids:
          unmatched_track_idx = track_ids.index(unmatched_track_id) # 在self.tracks里面，找到该未被匹配的id的index
          self.tracks[unmatched_track_idx].inactive += 1

          if self.tracks[unmatched_track_idx].inactive > self.patience:
            killed_track_ids.append(unmatched_track_id)

        # self.tracks = [] # <-- Needs to be updated
        self.tracks = [t for t in self.tracks
                       if t.id not in killed_track_ids]

        ##################
        ### TODO ends
        ##################        
        
        new_boxes_idx = set(range(len(boxes))) - set(seen_box_idx)
        new_boxes = [boxes[i] for i in new_boxes_idx]
        new_scores = [scores[i] for i in new_boxes_idx]
        new_features = [pred_features[i] for i in new_boxes_idx]
        self.add(new_boxes, new_scores, new_features)

# %%
# test the result of my code
tracker = LongTermReIDHungarianTracker(patience=20, obj_detect=None)
run_tracker(val_sequences, db=train_db, tracker=tracker, output_dir=None)
# Out:
# Tracking: MOT16-02
# Tracks found: 130
# Runtime for MOT16-02: 6.5 s.
# Tracking: MOT16-05
# Tracks found: 155
# Runtime for MOT16-05: 2.1 s.
# Tracking: MOT16-09
# Tracks found: 51
# Runtime for MOT16-09: 1.3 s.
# Tracking: MOT16-11
# Tracks found: 91
# Runtime for MOT16-11: 2.8 s.
# Runtime for all sequences: 12.8 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT  MT  PT ML   FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.2% 67.0% 36.4% 52.2% 96.1%  62  11  38 13  390  8873 142  220 49.4% 0.095
# MOT16-05 62.5% 74.0% 54.2% 68.8% 94.0% 133  56  65 12  305  2156 119  149 62.7% 0.142
# MOT16-09 56.6% 70.0% 47.5% 66.3% 97.7%  26  12  13  1   82  1793  41   83 64.0% 0.085
# MOT16-11 69.4% 76.5% 63.5% 80.2% 96.6%  75  44  25  6  266  1871  48   90 76.8% 0.083
# OVERALL  56.9% 71.5% 47.3% 63.5% 96.1% 296 123 141 32 1043 14693 350  542 60.0% 0.099
#               idf1       idp       idr  ...  num_fragmentations      mota      motp
# MOT16-02  0.472122  0.670430  0.364351  ...                 220  0.493838  0.094828
# MOT16-05  0.625386  0.739637  0.541709  ...                 149  0.627006  0.141822
# MOT16-09  0.566059  0.700055  0.475117  ...                  83  0.640188  0.085351
# MOT16-11  0.693693  0.764781  0.634697  ...                  90  0.768440  0.082838
# OVERALL   0.569361  0.715397  0.472838  ...                 542  0.600437  0.098722
#
# [5 rows x 15 columns]

# %%
# given to check the result
tracker = LongTermReIDHungarianTracker(patience=20, obj_detect=None)
run_tracker(val_sequences, db=train_db, tracker=tracker, output_dir=None)
# Out:
# Tracking: MOT16-02
# Tracks found: 130
# Runtime for MOT16-02: 7.1 s.
# Tracking: MOT16-05
# Tracks found: 155
# Runtime for MOT16-05: 2.0 s.
# Tracking: MOT16-09
# Tracks found: 51
# Runtime for MOT16-09: 1.3 s.
# Tracking: MOT16-11
# Tracks found: 91
# Runtime for MOT16-11: 3.1 s.
# Runtime for all sequences: 13.5 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT  MT  PT ML   FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.2% 67.0% 36.4% 52.2% 96.1%  62  11  38 13  390  8873 142  220 49.4% 0.095
# MOT16-05 62.5% 74.0% 54.2% 68.8% 94.0% 133  56  65 12  305  2156 119  149 62.7% 0.142
# MOT16-09 56.6% 70.0% 47.5% 66.3% 97.7%  26  12  13  1   82  1793  41   83 64.0% 0.085
# MOT16-11 69.4% 76.5% 63.5% 80.2% 96.6%  75  44  25  6  266  1871  48   90 76.8% 0.083
# OVERALL  56.9% 71.5% 47.3% 63.5% 96.1% 296 123 141 32 1043 14693 350  542 60.0% 0.099

# %% [markdown]
# ## Exercise Part II - Building a tracker based on Neural Message Passing
#
# Our ``LongTermReIDHungarianTracker`` is still limited when compared to current modern trackers. 上面这种方法还是有弊端的：1. 只考虑了appearance 来计算相似度，着不太好，最好还要考虑object position 和 size attributes。 2. 现在这个tracker只能 两两之间计算相似度，我们想要考虑更高层面的info。
#
# Firstly, it relies solely on appearance to predict similarity scores between objectes. This can be problematic whenever appearance alone may not discriminative, and it'd be best to also take into account object position and size attributes. Secondly, our tracker can only account for pairwise similarities among objects. Ideally, we would like it to also consider higher-order information.
#
# To address these limitations. We will now build a tracker that will combine both apperance and position information with a Message Passing Neural Network, inspired by the approach presented in [Learning a Neural Solver for Multiple Object Tracking, CVPR 2020](https://arxiv.org/abs/1912.07515)  所以我们开始构建一个tracker，既能考虑apperance又能考虑position的 Message Passing Neural Network 模型。
#
# The overall idea will be to build, for every tracking step, a bipartite graph containing two sets of nodes: past tracks, and detections in the current frame. We will initialize node features with ReID embeddings, and edge features with relative position features and ReID distance. We will use an MPN to refine these edge embeddings. The learning task will be to classify the edge embeddings in this graph, which is equivalent to predicting the entries of our data association similarity matrix.
#
# 一个双向graph，有两个sets of nodes：past tracks, and detections in the current frame. 边界(edges)表示relative position features and ReID distance

# %% [markdown]
# ### Building an MPN for Bipartite Graphs
#
# We will first build a Neural Message Passing layer based on the Graph Networks framework introduced in [Relational inductive biases, deep learning, and graph networks, arXiv 2020](https://arxiv.org/abs/1806.01261), as explained in the *A More General Framework* slides of [Lecture 5](https://www.moodle.tum.de/pluginfile.php/2928927/mod_resource/content/1/5.MOT2.pdf) (slides 70 to 75).
#
# 关于GNN 的一些维度上面的设置：
#
# We will be using a bipartite graph, i.e., we will have **two sets of nodes $A$ (past tracks), and $B$ (detections)**, and our **set of edges will be $A\times B$**. That is, we will connect every pair of past tracks and detections.
#
# We will have **initial node features** (i.e. reid embeddings) matrices: $X_A$ and $X_B$ and an initial edge features tensor $E$.
#
# $X_A$ and $X_B$ have shape $|A|\times \text{node_dim}$ and $|B|\times \text{node_dim}$, respectively.
#
# $E$ has shape $|A| \times |B| \times \text{edge_dim}$. Its $(i, j)$ entry contains the edge features of node $i$ in $A$ and node $j$ in $B$.
#
# With the given layer, we will produce new node feature matrices $X_A'$ and $X_B'$ and edge features $E'$ with the same dimensions.
# Please refer to the formulas in the slides and figure how to apply them in this setting.
#
# You are asked to implement both the node and edge update steps in the class below
#
# **NOTE 1**: Working with a bipartite graph allows us to vectorize all operations in the formulas in a straightforward manner (keep in mind that we store edge features in a matrix). Given a node in $A$, it is connected to all nodes in $B$.
#
# **NOTE 2**: You do not need to care about batching several graphs. This implementation will only work with a single graph at a time.

# %%
from torch import nn

class BipartiteNeuralMessagePassingLayer(nn.Module):    
    def __init__(self, node_dim, edge_dim, dropout=0.):
        super().__init__()

        edge_in_dim  = 2*node_dim + 2*edge_dim # 2*edge_dim since we always concatenate initial edge features
        self.edge_mlp = nn.Sequential(*[nn.Linear(edge_in_dim, edge_dim), nn.ReLU(), nn.Dropout(dropout), 
                                    nn.Linear(edge_dim, edge_dim), nn.ReLU(), nn.Dropout(dropout)])
        # MLP 是公式中的 learnable function

        node_in_dim  = node_dim + edge_dim
        self.node_mlp = nn.Sequential(*[nn.Linear(node_in_dim, node_dim), nn.ReLU(), nn.Dropout(dropout),  
                                        nn.Linear(node_dim, node_dim), nn.ReLU(), nn.Dropout(dropout)])

    def edge_update(self, edge_embeds, nodes_a_embeds, nodes_b_embeds):
        """
        Node-to-edge updates, as descibed in slide 71, lecture 5. 见新版slide，不是noteability里面的
        Args:
            edge_embeds: torch.Tensor with shape (|A|, |B|, 2 x edge_dim) 
            nodes_a_embeds: torch.Tensor with shape (|A|, node_dim)
            nodes_b_embeds: torch.Tensor with shape (|B|, node_dim)
            
        returns:
            updated_edge_feats = torch.Tensor with shape (|A|, |B|, edge_dim) 
        """
        
        n_nodes_a, n_nodes_b, _  = edge_embeds.shape # a 和 b 的nodes个数，实际上就是 已有tracks的个数和预测的tracks(detection)的个数
        
        ########################
        #### TODO starts
        ########################

        # edge_in = ... # has shape (|A|, |B|, 2*node_dim + 2*edge_dim)
        nodes_a_embeds_for_cat = torch.unsqueeze(nodes_a_embeds, 1).repeat(1, n_nodes_b, 1)  # shape (|A|, |B|, node_dim)
        nodes_b_embeds_for_cat = torch.unsqueeze(nodes_b_embeds, 0).repeat(n_nodes_a, 1, 1)  # shape (|A|, |B|, node_dim)
        edge_in = torch.cat((nodes_a_embeds_for_cat, edge_embeds, nodes_b_embeds_for_cat), 2) # shape (|A|, |B|, 2 * node_dim + 2 x edge_dim)
        
        ########################
        #### TODO ends
        ########################
        
        
        return self.edge_mlp(edge_in) # shape (|A|, |B|, edge_dim) 

    def node_update(self, edge_embeds, nodes_a_embeds, nodes_b_embeds):
        """
        Edge-to-node updates, as descibed in slide 75, lecture 5.

        Args:
            edge_embeds: torch.Tensor with shape (|A|, |B|, edge_dim) 
            nodes_a_embeds: torch.Tensor with shape (|A|, node_dim)
            nodes_b_embeds: torch.Tensor with shape (|B|, node_dim)
            
        returns:
            tuple(
                updated_nodes_a_embeds: torch.Tensor with shape (|A|, node_dim),
                updated_nodes_b_embeds: torch.Tensor with shape (|B|, node_dim)
                )
        """
        
        ########################
        #### TODO starts
        ########################
        
        # NOTE: Use 'sum' as aggregation function

        # nodes_a_in = ... # Has shape (|A|, node_dim + edge_dim) 
        # nodes_b_in = ... # Has shape (|B|, node_dim + edge_dim) 

        edge_embeds_a_sum = torch.sum(edge_embeds, dim=1)   # shape (|A|, edge_dim)
        nodes_a_in = torch.cat((edge_embeds_a_sum, nodes_a_embeds), 1)

        edge_embeds_b_sum = torch.sum(edge_embeds, dim=0)   # shape (|B|, edge_dim)
        nodes_b_in = torch.cat((edge_embeds_b_sum, nodes_b_embeds), 1)

        ########################
        #### TODO ends
        ########################

        nodes_a = self.node_mlp(nodes_a_in)
        nodes_b = self.node_mlp(nodes_b_in)

        return nodes_a, nodes_b

    def forward(self, edge_embeds, nodes_a_embeds, nodes_b_embeds):
        edge_embeds_latent = self.edge_update(edge_embeds, nodes_a_embeds, nodes_b_embeds)
        nodes_a_latent, nodes_b_latent = self.node_update(edge_embeds_latent, nodes_a_embeds, nodes_b_embeds)

        return edge_embeds_latent, nodes_a_latent, nodes_b_latent

# %% [markdown]
# ## Building the entire network to predict similarities
# We now build the network that generates initial node and edge features, performs neural message passing, and classifies edges（若edge是active，则表示edge两端的node是匹配的，两端是同一个人；若是inactive的，则反之） in order to produce the final costs that we will use for data association.
#
# You need to implement the method that computes the initial edge features. You can can follow [1] and, given a two bounding boxes $(x_i, y_i, w_i, h_i)$ and  $(x_j, y_j, w_j, h_j)$ and timestamps $t_i$ and $t_j$, compute an initial 5-dimensional edge feature vector as（下面就是edge feature, 是5D的）:
# $$ E_(i, j) = \left (\frac{2(x_j - x_i)}{h_i + h_j}, \frac{2(y_j - y_i)}{h_i + h_j}, \log{\frac{h_i}{h_j}}, \log{\frac{w_i}{w_j}}, t_j - t_i \right )$$
#
#
# Feel free to engineer your own features (e.g. use IoU, etc.)

# %%
from torch.nn import functional as F
class AssignmentSimilarityNet(nn.Module):  # 这个其实就是一个计算distance的方法
    def __init__(self, reid_network, node_dim, edge_dim, reid_dim, edges_in_dim, num_steps, dropout=0.):
        super().__init__()
        self.reid_network = reid_network
        self.graph_net = BipartiteNeuralMessagePassingLayer(node_dim=node_dim, edge_dim=edge_dim, dropout=dropout)
        self.num_steps = num_steps
        self.cnn_linear = nn.Linear(reid_dim, node_dim)
        self.edge_in_mlp = nn.Sequential(*[nn.Linear(edges_in_dim, edge_dim), nn.ReLU(), nn.Dropout(dropout), nn.Linear(edge_dim, edge_dim), nn.ReLU(),nn.Dropout(dropout)])
        self.classifier = nn.Sequential(*[nn.Linear(edge_dim, edge_dim), nn.ReLU(), nn.Linear(edge_dim, 1)])
        
    
    def compute_edge_feats(self, track_coords, current_coords, track_t, curr_t):    
        """
        Computes initial edge feature tensor

        Args:
            track_coords: track's frame box coordinates, given by top-left and bottom-right coordinates
                          torch.Tensor with shape (num_tracks, 4)
            current_coords: current frame box coordinates, given by top-left and bottom-right coordinates
                            has shape (num_boxes, 4)
                          
            track_t: track's timestamps, torch.Tensor with with shape (num_tracks, )
            curr_t: current frame's timestamps, torch.Tensor withwith shape (num_boxes,)        
            
        
        Returns:
            tensor with shape (num_trakcs, num_boxes, 5) containing pairwise
            position and time difference features 
        """

        ########################
        #### TODO starts
        ########################
        
        # NOTE 1: we recommend you to use box centers to compute distances
        # in the x and y coordinates.

        # NOTE 2: Check out the  code inside train_one_epoch function and 
        # LongTrackTrainingDataset class a few cells below to debug this

        # transform the coordinates to center-based coordinates. but keep the same dim
        track_center_based_coords = torch.cat((((track_coords[:, 0] + track_coords[:, 2])/2).reshape(-1, 1), ((track_coords[:, 1] + track_coords[:, 3])/2).reshape(-1, 1), 
                                               (track_coords[:, 2]-track_coords[:, 0]).reshape(-1, 1), (track_coords[:, 1] - track_coords[:, 3]).reshape(-1, 1)), 1)
        # shape (num_tracks, 4), (xi,yi,wi,hi)
        current_center_based_coords = torch.cat((((current_coords[:, 0] + current_coords[:, 2])/2).reshape(-1, 1), ((current_coords[:, 1] + current_coords[:, 3])/2).reshape(-1, 1), 
                                               (current_coords[:, 2]-current_coords[:, 0]).reshape(-1, 1), (current_coords[:, 1] - current_coords[:, 3]).reshape(-1, 1)), 1)
        # shape (num_boxes, 4), (xj,yj,wj,hj)

        num_tracks = track_coords.shape[0]
        num_boxes = current_coords.shape[0]
        edge_feats = torch.zeros(num_tracks, num_boxes, 5)
        for i in range(num_tracks):
          for j in range(num_boxes):
            edge_feats[i, j, 0] = 2 * (current_center_based_coords[j, 0] - track_center_based_coords[i, 0]) / (current_center_based_coords[j, 3] + track_center_based_coords[i, 3])
            edge_feats[i, j, 1] = 2 * (current_center_based_coords[j, 1] - track_center_based_coords[i, 1]) / (current_center_based_coords[j, 3] + track_center_based_coords[i, 3])
            edge_feats[i, j, 2] = torch.log(track_center_based_coords[i, 3] / current_center_based_coords[j, 3])
            edge_feats[i, j, 3] = torch.log(track_center_based_coords[i, 2] / current_center_based_coords[j, 2])
            edge_feats[i, j, 4] = curr_t[j] - track_t[i]

        ########################
        #### TODO ends
        ########################

        return edge_feats # has shape (num_tracks, num_boxes, 5)


    def forward(self, track_app, current_app, track_coords, current_coords, track_t, curr_t):
        """
        Args:
            track_app: track's reid embeddings, torch.Tensor with shape (num_tracks, 512)  reid网络输出的features
            current_app: current frame detections' reid embeddings, torch.Tensor with shape (num_boxes, 512)
            track_coords: track's frame box coordinates, given by top-left and bottom-right coordinates
                          torch.Tensor with shape (num_tracks, 4)
            current_coords: current frame box coordinates, given by top-left and bottom-right coordinates
                            has shape (num_boxes, 4)
                          
            track_t: track's timestamps, torch.Tensor with with shape (num_tracks, )
            curr_t: current frame's timestamps, torch.Tensor withwith shape (num_boxes,)
            
        Returns:
            classified edges: torch.Tensor with shape (num_steps, num_tracks, num_boxes),
                             containing at entry (step, i, j) the unnormalized probability that track i and 
                             detection j are a match, according to the classifier at the given neural message passing step
        """
        
        # Get initial edge embeddings to 见slide 61. 这里是将上面那个函数得到的初始edge_feats和用reid模型跑出来的embeddings的distance，作concatenate,然后作为初始的initial_edge_embeds，进行Neural Message Passing更新
        dist_reid = cosine_distance(track_app, current_app).cuda()
        pos_edge_feats = self.compute_edge_feats(track_coords, current_coords, track_t, curr_t).cuda()  # has shape (num_tracks, num_boxes, 5)
        # print(dist_reid.is_cuda, pos_edge_feats.is_cuda) # true false
        edge_feats = torch.cat((pos_edge_feats, dist_reid.unsqueeze(-1)), dim=-1)  # 把reid算出来的feature(embeddings)和initial edge_feats 拼在一起得到一个初始的features
        # con((A, B, 5), (A, B, 1)) = (A, B, 6) A:num_tracks; B:num_boxes
        edge_embeds = self.edge_in_mlp(edge_feats)  # (A, B, edge_dim)
        initial_edge_embeds = edge_embeds.clone()

        # Get initial node embeddings, reduce dimensionality from 512 to node_dim
        track_embeds = F.relu(self.cnn_linear(track_app))  # self.cnn_linear = nn.Linear(reid_dim, node_dim)， 把512 变成node_dim
        curr_embeds = F.relu(self.cnn_linear(current_app))

        classified_edges = []
        for _ in range(self.num_steps):
            edge_embeds = torch.cat((edge_embeds, initial_edge_embeds), dim=-1) # 总是把两个一样的edge_embeds拼在一起       
            edge_embeds, track_embeds, curr_embeds = self.graph_net(edge_embeds=edge_embeds, nodes_a_embeds=track_embeds, nodes_b_embeds=curr_embeds) # edge_embeds (A, B, edge_dim)

            classified_edges.append(self.classifier(edge_embeds)) # 一个分类器  self.classifier(edge_embeds)-->(A, B, 1)

        return torch.stack(classified_edges).squeeze(-1) # 结果是 shape (num_steps, num_tracks, num_boxes), 每个step的，已有tracks和 预测boxes的 匹配度，是一个没有normalize的概率
        # torch.stack(classified_edges) --> (num_step, A, B, 1), and squeeze the last dim

# %% [markdown]
# ## Putting everything together

# %% [markdown]
# Finally, we incorporate our ``AssignmentSimilarityNet`` into our tracker. We can keep everything as in ``LongTermReIDHungarianTracker`` except for the distance computation, which is now directly obtained via a forward pass through AssignmentSimilarityNet.

# %%
_UNMATCHED_COST=255
class MPNTracker(LongTermReIDHungarianTracker):
    def __init__(self, assign_net, *args, **kwargs):
        self.assign_net = assign_net
        super().__init__(*args, **kwargs)
        
    def data_association(self, boxes, scores, pred_features):  
        if self.tracks:  
            track_boxes = torch.stack([t.box for t in self.tracks], axis=0).cuda()
            track_features = torch.stack([t.get_feature() for t in self.tracks], axis=0).cuda()
            
            # Hacky way to recover the timestamps of boxes and tracks
            curr_t = self.im_index * torch.ones((pred_features.shape[0],)).cuda()
            track_t = torch.as_tensor([self.im_index - t.inactive - 1 for t in self.tracks]).cuda()

            ########################
            #### TODO starts
            ########################
            
            # Do a forward pass through self.assign_net to obtain our costs.
            # Note: self.assign_net will return unnormalized probabilities. 
            # Make sure to apply the sigmoid function to them!

            classified_edges = self.assign_net(track_features, pred_features.cuda(), track_boxes, boxes.cuda(), track_t, curr_t)  # track_features其实就是它的reid features, track_box就是它的已有的tracks的box，左上和右下。
            # shape (num_steps, num_tracks, num_boxes)
            pred_sim = torch.sigmoid(classified_edges).cpu().detach().numpy()

            ########################
            #### TODO ends
            ########################

            pred_sim = pred_sim[-1]  # Use predictions at last message passing step。pred_sim[0]表示第一个step, pred_sim[-1]表示第10个step。
            distance = (1- pred_sim)  # 用这个当distance
            
            # Do not allow mataches when sim < 0.5, to avoid low-confident associations
            distance = np.where(pred_sim < 0.5, _UNMATCHED_COST, distance) 

            # Perform Hungarian matching.
            row_idx, col_idx = linear_assignment(distance)            
            self.update_tracks(row_idx, col_idx,distance, boxes, scores, pred_features)

            
        else:
            # No tracks exist.
            self.add(boxes, scores, pred_features)

# %% [markdown]
# ## Training and evaluating our model
#
# We provide all boilerplate code for training our neural message passing based
# tracker, as well as evaluating.
#
# Under the hood, we are sampling frames randomly from our training sequences, and then sampling boxes from past frames as past_tracks to generate our
# training
# data. Check out `LongTrackTrainingDataset` for details.
#
# We train the model with a weighted cross-entropy loss
# to account for the class imbalance. Check out `train_one_epoch` if you're
# interested.
#
# No need to write any code from your side here!

# %%
from gnn.dataset import LongTrackTrainingDataset
from torch.utils.data import DataLoader
from gnn.trainer import train_one_epoch

MAX_PATIENCE = 20
MAX_EPOCHS = 15
EVAL_FREQ = 1


# Define our model, and init 
assign_net = AssignmentSimilarityNet(reid_network=None, # Not needed since we work with precomputed features
                                     node_dim=32, 
                                     edge_dim=64, 
                                     reid_dim=512, 
                                     edges_in_dim=6, 
                                     num_steps=10).cuda()

# We only keep two sequences for validation. You can
dataset = LongTrackTrainingDataset(dataset='MOT16-train_wo_val2', 
                                   db=train_db, 
                                   root_dir= osp.join(root_dir, 'data/MOT16'),
                                   max_past_frames = MAX_PATIENCE,
                                   vis_threshold=0.25)

data_loader = DataLoader(dataset, batch_size=8, collate_fn = lambda x: x, 
                         shuffle=True, num_workers=2, drop_last=True)
device = torch.device('cuda')
optimizer = torch.optim.Adam(assign_net.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5)

# %% [markdown]
# We only leave 2 sequences for validation in order to maximize
# the amount of training data. For your convenience, here are the
#  LongTermReIDTracker results on them. Your validation IDF1 scores should show an improvement of ~0.5 over them.
# ```
#
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.2% 67.0% 36.4% 52.2% 96.1%  62 11 38 13 390  8873 142  220 49.4% 0.095
# MOT16-11 69.4% 76.5% 63.5% 80.2% 96.6%  75 44 25  6 266  1871  48   90 76.8% 0.083
# OVERALL  55.5% 71.2% 45.5% 61.7% 96.3% 137 55 63 19 656 10744 190  310 58.6% 0.090
# ```

# %% [markdown]
# Let's start training!
#
# Note that we have observed quite a lot of noise in validation scores among epochs and runs. This can be explained due to the small size of our training and
# validation sets, that's why we perform early stopping to obtain the best performing model on validation.

# %%
# test my own codes
best_idf1 = 0.
for epoch in range(1, MAX_EPOCHS + 1):
    print(f"-------- EPOCH {epoch:2d} --------")
    train_one_epoch(model = assign_net, data_loader=data_loader, optimizer=optimizer, print_freq=100)
    scheduler.step()

    if epoch % EVAL_FREQ == 0:
        tracker =  MPNTracker(assign_net=assign_net.eval(), obj_detect=None, patience=MAX_PATIENCE)
        val_sequences = MOT16Sequences('MOT16-val2', osp.join(root_dir, 'data/MOT16'), vis_threshold=0.)
        res = run_tracker(val_sequences, db=train_db, tracker=tracker, output_dir=None)
        idf1 = res.loc['OVERALL']['idf1']
        if idf1 > best_idf1:
            best_idf1 = idf1
            torch.save(assign_net.state_dict(), osp.join(root_dir, 'output', 'best_ckpt.pth'))
# Out:
# -------- EPOCH  1 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.734. Accuracy: 0.938. Recall: 0.723. Precision: 0.460
# Iter 200. Loss: 0.099. Accuracy: 0.992. Recall: 0.986. Precision: 0.892
# Iter 300. Loss: 0.073. Accuracy: 0.991. Recall: 0.992. Precision: 0.895
# Iter 400. Loss: 0.068. Accuracy: 0.992. Recall: 0.990. Precision: 0.911
# Tracking: MOT16-02
# Tracks found: 206
# Runtime for MOT16-02: 96.3 s.
# Tracking: MOT16-11
# Tracks found: 131
# Runtime for MOT16-11: 45.0 s.
# Runtime for all sequences: 141.3 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.0% 66.8% 36.3% 52.2% 96.1%  62 11 38 13 390  8873 133  215 49.4% 0.095
# MOT16-11 67.0% 73.8% 61.3% 80.2% 96.6%  75 44 24  7 266  1871  55   88 76.8% 0.082
# OVERALL  54.5% 69.9% 44.7% 61.7% 96.3% 137 55 62 20 656 10744 188  303 58.6% 0.089
# -------- EPOCH  2 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.038. Accuracy: 0.995. Recall: 0.994. Precision: 0.940
# Iter 200. Loss: 0.050. Accuracy: 0.994. Recall: 0.991. Precision: 0.940
# Iter 300. Loss: 0.034. Accuracy: 0.997. Recall: 0.995. Precision: 0.957
# Iter 400. Loss: 0.034. Accuracy: 0.998. Recall: 0.995. Precision: 0.978
# Tracking: MOT16-02
# Tracks found: 121
# Runtime for MOT16-02: 89.9 s.
# Tracking: MOT16-11
# Tracks found: 96
# Runtime for MOT16-11: 43.8 s.
# Runtime for all sequences: 133.7 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 46.8% 66.5% 36.1% 52.2% 96.1%  62 11 38 13 390  8873 106  219 49.6% 0.095
# MOT16-11 70.9% 78.2% 64.9% 80.2% 96.6%  75 44 24  7 266  1871  35   90 77.0% 0.083
# OVERALL  55.9% 71.6% 45.8% 61.7% 96.3% 137 55 62 20 656 10744 141  309 58.8% 0.090
# -------- EPOCH  3 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.023. Accuracy: 0.999. Recall: 0.996. Precision: 0.986
# Iter 200. Loss: 0.015. Accuracy: 0.999. Recall: 0.997. Precision: 0.988
# Iter 300. Loss: 0.015. Accuracy: 0.999. Recall: 0.998. Precision: 0.988
# Iter 400. Loss: 0.015. Accuracy: 0.999. Recall: 0.999. Precision: 0.987
# Tracking: MOT16-02
# Tracks found: 105
# Runtime for MOT16-02: 90.1 s.
# Tracking: MOT16-11
# Tracks found: 88
# Runtime for MOT16-11: 43.6 s.
# Runtime for all sequences: 133.7 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.8% 67.8% 36.9% 52.2% 96.1%  62 11 38 13 390  8873 100  221 49.6% 0.095
# MOT16-11 71.0% 78.3% 64.9% 80.2% 96.6%  75 44 24  7 266  1871  34   90 77.0% 0.083
# OVERALL  56.5% 72.4% 46.3% 61.7% 96.3% 137 55 62 20 656 10744 134  311 58.8% 0.090
# -------- EPOCH  4 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.013. Accuracy: 0.999. Recall: 0.998. Precision: 0.987
# Iter 200. Loss: 0.018. Accuracy: 0.998. Recall: 0.997. Precision: 0.983
# Iter 300. Loss: 0.013. Accuracy: 0.999. Recall: 0.999. Precision: 0.986
# Iter 400. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Tracking: MOT16-02
# Tracks found: 112
# Runtime for MOT16-02: 90.8 s.
# Tracking: MOT16-11
# Tracks found: 92
# Runtime for MOT16-11: 43.4 s.
# Runtime for all sequences: 134.3 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.4% 67.3% 36.6% 52.2% 96.1%  62 11 38 13 390  8873 105  219 49.6% 0.095
# MOT16-11 71.7% 79.0% 65.6% 80.2% 96.6%  75 44 24  7 266  1871  37   90 77.0% 0.083
# OVERALL  56.5% 72.4% 46.4% 61.7% 96.3% 137 55 62 20 656 10744 142  309 58.8% 0.090
# -------- EPOCH  5 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.015. Accuracy: 0.999. Recall: 0.998. Precision: 0.991
# Iter 200. Loss: 0.050. Accuracy: 0.998. Recall: 0.993. Precision: 0.983
# Iter 300. Loss: 0.019. Accuracy: 0.999. Recall: 0.996. Precision: 0.991
# Iter 400. Loss: 0.017. Accuracy: 0.999. Recall: 0.998. Precision: 0.988
# Tracking: MOT16-02
# Tracks found: 97
# Runtime for MOT16-02: 88.9 s.
# Tracking: MOT16-11
# Tracks found: 85
# Runtime for MOT16-11: 43.0 s.
# Runtime for all sequences: 131.9 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 48.5% 68.8% 37.4% 52.2% 96.1%  62 11 38 13 390  8873 102  219 49.6% 0.095
# MOT16-11 70.1% 77.3% 64.2% 80.2% 96.6%  75 44 24  7 266  1871  34   90 77.0% 0.083
# OVERALL  56.6% 72.5% 46.4% 61.7% 96.3% 137 55 62 20 656 10744 136  309 58.8% 0.090
# -------- EPOCH  6 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.012. Accuracy: 0.999. Recall: 0.998. Precision: 0.986
# Iter 200. Loss: 0.014. Accuracy: 0.999. Recall: 0.998. Precision: 0.988
# Iter 300. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.988
# Iter 400. Loss: 0.011. Accuracy: 0.999. Recall: 0.999. Precision: 0.992
# Tracking: MOT16-02
# Tracks found: 100
# Runtime for MOT16-02: 90.8 s.
# Tracking: MOT16-11
# Tracks found: 86
# Runtime for MOT16-11: 43.7 s.
# Runtime for all sequences: 134.6 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 48.3% 68.5% 37.2% 52.2% 96.1%  62 11 38 13 390  8873 102  219 49.6% 0.095
# MOT16-11 70.0% 77.1% 64.0% 80.2% 96.6%  75 44 24  7 266  1871  35   90 77.0% 0.083
# OVERALL  56.4% 72.3% 46.3% 61.7% 96.3% 137 55 62 20 656 10744 137  309 58.8% 0.090
# -------- EPOCH  7 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.011. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
# Iter 200. Loss: 0.012. Accuracy: 0.999. Recall: 0.999. Precision: 0.988
# Iter 300. Loss: 0.012. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Iter 400. Loss: 0.008. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Tracking: MOT16-02
# Tracks found: 99
# Runtime for MOT16-02: 89.8 s.
# Tracking: MOT16-11
# Tracks found: 86
# Runtime for MOT16-11: 43.5 s.
# Runtime for all sequences: 133.3 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.4% 67.3% 36.5% 52.2% 96.1%  62 11 38 13 390  8873 102  221 49.6% 0.095
# MOT16-11 70.7% 78.0% 64.7% 80.2% 96.6%  75 44 24  7 266  1871  35   90 77.0% 0.083
# OVERALL  56.1% 71.9% 46.0% 61.7% 96.3% 137 55 62 20 656 10744 137  311 58.8% 0.090
# -------- EPOCH  8 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.011. Accuracy: 0.999. Recall: 0.998. Precision: 0.990
# Iter 200. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.991
# Iter 300. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
# Iter 400. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Tracking: MOT16-02
# Tracks found: 99
# Runtime for MOT16-02: 90.3 s.
# Tracking: MOT16-11
# Tracks found: 85
# Runtime for MOT16-11: 43.7 s.
# Runtime for all sequences: 134.0 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 48.3% 68.6% 37.3% 52.2% 96.1%  62 11 38 13 390  8873 100  221 49.6% 0.095
# MOT16-11 70.7% 78.0% 64.7% 80.2% 96.6%  75 44 24  7 266  1871  33   90 77.0% 0.083
# OVERALL  56.7% 72.7% 46.5% 61.7% 96.3% 137 55 62 20 656 10744 133  311 58.8% 0.090
# -------- EPOCH  9 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.009. Accuracy: 0.999. Recall: 0.999. Precision: 0.991
# Iter 200. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.991
# Iter 300. Loss: 0.011. Accuracy: 0.999. Recall: 0.999. Precision: 0.988
# Iter 400. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
# Tracking: MOT16-02
# Tracks found: 100
# Runtime for MOT16-02: 90.8 s.
# Tracking: MOT16-11
# Tracks found: 88
# Runtime for MOT16-11: 44.4 s.
# Runtime for all sequences: 135.2 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 48.3% 68.6% 37.3% 52.2% 96.1%  62 11 38 13 390  8873 100  221 49.6% 0.095
# MOT16-11 70.8% 78.0% 64.7% 80.2% 96.6%  75 44 24  7 266  1871  34   90 77.0% 0.083
# OVERALL  56.7% 72.7% 46.5% 61.7% 96.3% 137 55 62 20 656 10744 134  311 58.8% 0.090
# -------- EPOCH 10 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
# Iter 200. Loss: 0.009. Accuracy: 0.999. Recall: 0.999. Precision: 0.988
# Iter 300. Loss: 0.012. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
# Iter 400. Loss: 0.008. Accuracy: 0.999. Recall: 0.998. Precision: 0.991
# Tracking: MOT16-02
# Tracks found: 96
# Runtime for MOT16-02: 93.0 s.
# Tracking: MOT16-11
# Tracks found: 84
# Runtime for MOT16-11: 44.8 s.
# Runtime for all sequences: 137.8 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 48.1% 68.3% 37.1% 52.2% 96.1%  62 11 38 13 390  8873 100  221 49.6% 0.095
# MOT16-11 69.2% 76.3% 63.3% 80.2% 96.6%  75 44 24  7 266  1871  36   90 77.0% 0.083
# OVERALL  56.0% 71.8% 45.9% 61.7% 96.3% 137 55 62 20 656 10744 136  311 58.8% 0.090
# -------- EPOCH 11 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
# Iter 200. Loss: 0.011. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
# Iter 300. Loss: 0.013. Accuracy: 0.999. Recall: 0.998. Precision: 0.989
# Iter 400. Loss: 0.008. Accuracy: 0.999. Recall: 0.999. Precision: 0.992
# Tracking: MOT16-02
# Tracks found: 98
# Runtime for MOT16-02: 92.4 s.
# Tracking: MOT16-11
# Tracks found: 86
# Runtime for MOT16-11: 45.3 s.
# Runtime for all sequences: 137.7 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 48.1% 68.3% 37.1% 52.2% 96.1%  62 11 38 13 390  8873 100  221 49.6% 0.095
# MOT16-11 69.6% 76.7% 63.6% 80.2% 96.6%  75 44 24  7 266  1871  36   90 77.0% 0.083
# OVERALL  56.1% 71.9% 46.0% 61.7% 96.3% 137 55 62 20 656 10744 136  311 58.8% 0.090
# -------- EPOCH 12 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Iter 200. Loss: 0.009. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
# Iter 300. Loss: 0.008. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Iter 400. Loss: 0.012. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
# Tracking: MOT16-02
# Tracks found: 99
# Runtime for MOT16-02: 93.4 s.
# Tracking: MOT16-11
# Tracks found: 87
# Runtime for MOT16-11: 45.0 s.
# Runtime for all sequences: 138.4 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 48.1% 68.3% 37.1% 52.2% 96.1%  62 11 38 13 390  8873 100  221 49.6% 0.095
# MOT16-11 69.6% 76.7% 63.6% 80.2% 96.6%  75 44 24  7 266  1871  36   90 77.0% 0.083
# OVERALL  56.1% 71.9% 46.0% 61.7% 96.3% 137 55 62 20 656 10744 136  311 58.8% 0.090
# -------- EPOCH 13 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.009. Accuracy: 0.999. Recall: 0.999. Precision: 0.991
# Iter 200. Loss: 0.009. Accuracy: 0.999. Recall: 0.999. Precision: 0.991
# Iter 300. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
# Iter 400. Loss: 0.011. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Tracking: MOT16-02
# Tracks found: 100
# Runtime for MOT16-02: 92.6 s.
# Tracking: MOT16-11
# Tracks found: 88
# Runtime for MOT16-11: 45.0 s.
# Runtime for all sequences: 137.6 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.9% 68.0% 36.9% 52.2% 96.1%  62 11 38 13 390  8873 100  221 49.6% 0.095
# MOT16-11 70.2% 77.4% 64.2% 80.2% 96.6%  75 44 24  7 266  1871  36   90 77.0% 0.083
# OVERALL  56.3% 72.1% 46.1% 61.7% 96.3% 137 55 62 20 656 10744 136  311 58.8% 0.090
# -------- EPOCH 14 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.009. Accuracy: 0.999. Recall: 0.999. Precision: 0.991
# Iter 200. Loss: 0.010. Accuracy: 0.999. Recall: 0.998. Precision: 0.991
# Iter 300. Loss: 0.009. Accuracy: 0.999. Recall: 0.999. Precision: 0.991
# Iter 400. Loss: 0.007. Accuracy: 0.999. Recall: 1.000. Precision: 0.992
# Tracking: MOT16-02
# Tracks found: 99
# Runtime for MOT16-02: 93.1 s.
# Tracking: MOT16-11
# Tracks found: 88
# Runtime for MOT16-11: 45.2 s.
# Runtime for all sequences: 138.2 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 48.1% 68.3% 37.1% 52.2% 96.1%  62 11 38 13 390  8873 100  221 49.6% 0.095
# MOT16-11 70.2% 77.4% 64.2% 80.2% 96.6%  75 44 24  7 266  1871  36   90 77.0% 0.083
# OVERALL  56.4% 72.2% 46.2% 61.7% 96.3% 137 55 62 20 656 10744 136  311 58.8% 0.090
# -------- EPOCH 15 --------
# 0it [00:00, ?it/s]
# Iter 100. Loss: 0.009. Accuracy: 0.999. Recall: 0.999. Precision: 0.991
# Iter 200. Loss: 0.009. Accuracy: 0.999. Recall: 1.000. Precision: 0.990
# Iter 300. Loss: 0.009. Accuracy: 0.999. Recall: 0.999. Precision: 0.992
# Iter 400. Loss: 0.009. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Tracking: MOT16-02
# Tracks found: 100
# Runtime for MOT16-02: 92.5 s.
# Tracking: MOT16-11
# Tracks found: 88
# Runtime for MOT16-11: 45.0 s.
# Runtime for all sequences: 137.4 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.9% 68.0% 36.9% 52.2% 96.1%  62 11 38 13 390  8873 100  221 49.6% 0.095
# MOT16-11 70.2% 77.4% 64.2% 80.2% 96.6%  75 44 24  7 266  1871  36   90 77.0% 0.083
# OVERALL  56.3% 72.1% 46.1% 61.7% 96.3% 137 55 62 20 656 10744 136  311 58.8% 0.090

# %%
# given to test my results
best_idf1 = 0.
for epoch in range(1, MAX_EPOCHS + 1):
    print(f"-------- EPOCH {epoch:2d} --------")
    train_one_epoch(model = assign_net, data_loader=data_loader, optimizer=optimizer, print_freq=100)
    scheduler.step()

    if epoch % EVAL_FREQ == 0:
        tracker =  MPNTracker(assign_net=assign_net.eval(), obj_detect=None, patience=MAX_PATIENCE)
        val_sequences = MOT16Sequences('MOT16-val2', osp.join(root_dir, 'data/MOT16'), vis_threshold=0.)
        res = run_tracker(val_sequences, db=train_db, tracker=tracker, output_dir=None)
        idf1 = res.loc['OVERALL']['idf1']
        if idf1 > best_idf1:
            best_idf1 = idf1
            torch.save(assign_net.state_dict(), osp.join(root_dir, 'output', 'best_ckpt.pth'))
# Out:
# -------- EPOCH  1 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.520. Accuracy: 0.955. Recall: 0.804. Precision: 0.609
# Iter 200. Loss: 0.084. Accuracy: 0.993. Recall: 0.986. Precision: 0.928
# Iter 300. Loss: 0.077. Accuracy: 0.995. Recall: 0.987. Precision: 0.938
# Iter 400. Loss: 0.046. Accuracy: 0.997. Recall: 0.990. Precision: 0.965
#
# Tracking: MOT16-02
# Tracks found: 124
# Runtime for MOT16-02: 9.2 s.
# Tracking: MOT16-11
# Tracks found: 88
# Runtime for MOT16-11: 8.2 s.
# Runtime for all sequences: 17.4 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 45.9% 65.2% 35.4% 52.2% 96.1%  62 11 38 13 390  8873 133  220 49.4% 0.095
# MOT16-11 67.6% 74.5% 61.9% 80.2% 96.6%  75 44 24  7 266  1871  46   90 76.9% 0.083
# OVERALL  54.0% 69.3% 44.3% 61.7% 96.3% 137 55 62 20 656 10744 179  310 58.7% 0.090
# -------- EPOCH  2 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.022. Accuracy: 0.999. Recall: 0.997. Precision: 0.991
# Iter 200. Loss: 0.021. Accuracy: 0.999. Recall: 0.998. Precision: 0.991
# Iter 300. Loss: 0.018. Accuracy: 0.999. Recall: 0.998. Precision: 0.989
# Iter 400. Loss: 0.022. Accuracy: 0.999. Recall: 0.997. Precision: 0.984
#
# Tracking: MOT16-02
# Tracks found: 106
# Runtime for MOT16-02: 9.4 s.
# Tracking: MOT16-11
# Tracks found: 86
# Runtime for MOT16-11: 8.0 s.
# Runtime for all sequences: 17.4 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 49.9% 70.9% 38.5% 52.2% 96.1%  62 12 37 13 390  8873 102  214 49.6% 0.090
# MOT16-11 70.0% 77.2% 64.1% 80.2% 96.6%  75 44 24  7 266  1871  36   90 77.0% 0.083
# OVERALL  57.5% 73.7% 47.1% 61.7% 96.3% 137 56 61 20 656 10744 138  304 58.8% 0.087
# -------- EPOCH  3 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.019. Accuracy: 0.999. Recall: 0.998. Precision: 0.986
# Iter 200. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.992
# Iter 300. Loss: 0.019. Accuracy: 0.999. Recall: 0.998. Precision: 0.987
# Iter 400. Loss: 0.014. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
#
# Tracking: MOT16-02
# Tracks found: 92
# Runtime for MOT16-02: 9.3 s.
# Tracking: MOT16-11
# Tracks found: 78
# Runtime for MOT16-11: 8.2 s.
# Runtime for all sequences: 17.4 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.3% 67.2% 36.5% 52.2% 96.1%  62 11 38 13 390  8873  98  220 49.6% 0.095
# MOT16-11 71.2% 78.5% 65.1% 80.2% 96.6%  75 44 24  7 266  1871  36   90 77.0% 0.083
# OVERALL  56.3% 72.2% 46.2% 61.7% 96.3% 137 55 62 20 656 10744 134  310 58.8% 0.090
# -------- EPOCH  4 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.013. Accuracy: 0.999. Recall: 0.999. Precision: 0.987
# Iter 200. Loss: 0.011. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Iter 300. Loss: 0.010. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
# Iter 400. Loss: 0.032. Accuracy: 0.996. Recall: 0.997. Precision: 0.970
#
# Tracking: MOT16-02
# Tracks found: 108
# Runtime for MOT16-02: 9.3 s.
# Tracking: MOT16-11
# Tracks found: 82
# Runtime for MOT16-11: 8.3 s.
# Runtime for all sequences: 17.5 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.8% 67.9% 36.9% 52.2% 96.1%  62 11 38 13 390  8873  98  222 49.6% 0.096
# MOT16-11 69.6% 76.7% 63.6% 80.2% 96.6%  75 44 24  7 266  1871  37   90 77.0% 0.083
# OVERALL  56.0% 71.8% 45.9% 61.7% 96.3% 137 55 62 20 656 10744 135  312 58.8% 0.090
# -------- EPOCH  5 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.010. Accuracy: 0.999. Recall: 0.998. Precision: 0.989
# Iter 200. Loss: 18.099. Accuracy: 0.985. Recall: 0.922. Precision: 0.857
# Iter 300. Loss: 0.049. Accuracy: 0.998. Recall: 0.991. Precision: 0.986
# Iter 400. Loss: 0.042. Accuracy: 0.999. Recall: 0.993. Precision: 0.987
#
# Tracking: MOT16-02
# Tracks found: 111
# Runtime for MOT16-02: 9.3 s.
# Tracking: MOT16-11
# Tracks found: 96
# Runtime for MOT16-11: 8.3 s.
# Runtime for all sequences: 17.6 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 48.1% 68.3% 37.1% 52.2% 96.1%  62 11 38 13 390  8873 102  223 49.6% 0.095
# MOT16-11 70.4% 77.6% 64.4% 80.2% 96.6%  75 44 24  7 266  1871  41   90 76.9% 0.083
# OVERALL  56.5% 72.3% 46.3% 61.7% 96.3% 137 55 62 20 656 10744 143  313 58.8% 0.090
# -------- EPOCH  6 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.027. Accuracy: 0.999. Recall: 0.998. Precision: 0.991
# Iter 200. Loss: 0.023. Accuracy: 0.999. Recall: 0.997. Precision: 0.988
# Iter 300. Loss: 0.023. Accuracy: 0.999. Recall: 0.998. Precision: 0.989
# Iter 400. Loss: 0.022. Accuracy: 0.999. Recall: 0.998. Precision: 0.989
#
# Tracking: MOT16-02
# Tracks found: 98
# Runtime for MOT16-02: 9.3 s.
# Tracking: MOT16-11
# Tracks found: 91
# Runtime for MOT16-11: 8.2 s.
# Runtime for all sequences: 17.5 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.6% 67.5% 36.7% 52.2% 96.1%  62 11 38 13 390  8873 102  224 49.6% 0.096
# MOT16-11 70.0% 77.2% 64.0% 80.2% 96.6%  75 44 24  7 266  1871  40   90 76.9% 0.083
# OVERALL  56.0% 71.7% 45.9% 61.7% 96.3% 137 55 62 20 656 10744 142  314 58.8% 0.090
# -------- EPOCH  7 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.022. Accuracy: 0.999. Recall: 0.997. Precision: 0.990
# Iter 200. Loss: 0.020. Accuracy: 0.999. Recall: 0.998. Precision: 0.989
# Iter 300. Loss: 0.023. Accuracy: 0.999. Recall: 0.997. Precision: 0.988
# Iter 400. Loss: 0.020. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
#
# Tracking: MOT16-02
# Tracks found: 107
# Runtime for MOT16-02: 9.3 s.
# Tracking: MOT16-11
# Tracks found: 92
# Runtime for MOT16-11: 8.3 s.
# Runtime for all sequences: 17.6 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.8% 67.8% 36.9% 52.2% 96.1%  62 11 38 13 390  8873 104  223 49.6% 0.095
# MOT16-11 70.2% 77.4% 64.3% 80.2% 96.6%  75 44 24  7 266  1871  41   90 76.9% 0.083
# OVERALL  56.2% 72.0% 46.1% 61.7% 96.3% 137 55 62 20 656 10744 145  313 58.8% 0.090
# -------- EPOCH  8 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.022. Accuracy: 0.999. Recall: 0.997. Precision: 0.989
# Iter 200. Loss: 0.018. Accuracy: 0.999. Recall: 0.999. Precision: 0.987
# Iter 300. Loss: 0.023. Accuracy: 0.999. Recall: 0.998. Precision: 0.990
# Iter 400. Loss: 0.023. Accuracy: 0.998. Recall: 0.998. Precision: 0.986
#
# Tracking: MOT16-02
# Tracks found: 98
# Runtime for MOT16-02: 9.4 s.
# Tracking: MOT16-11
# Tracks found: 90
# Runtime for MOT16-11: 8.1 s.
# Runtime for all sequences: 17.4 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 48.3% 68.6% 37.3% 52.2% 96.1%  62 11 38 13 390  8873  99  223 49.6% 0.095
# MOT16-11 70.2% 77.4% 64.3% 80.2% 96.6%  75 44 24  7 266  1871  40   90 76.9% 0.083
# OVERALL  56.5% 72.4% 46.4% 61.7% 96.3% 137 55 62 20 656 10744 139  313 58.8% 0.090
# -------- EPOCH  9 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.018. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Iter 200. Loss: 0.018. Accuracy: 0.999. Recall: 0.998. Precision: 0.988
# Iter 300. Loss: 0.019. Accuracy: 0.999. Recall: 0.997. Precision: 0.988
# Iter 400. Loss: 0.021. Accuracy: 0.999. Recall: 0.998. Precision: 0.988
#
# Tracking: MOT16-02
# Tracks found: 95
# Runtime for MOT16-02: 9.3 s.
# Tracking: MOT16-11
# Tracks found: 88
# Runtime for MOT16-11: 8.3 s.
# Runtime for all sequences: 17.6 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.3% 67.2% 36.5% 52.2% 96.1%  62 11 38 13 390  8873  99  223 49.6% 0.095
# MOT16-11 70.2% 77.4% 64.3% 80.2% 96.6%  75 44 24  7 266  1871  40   90 76.9% 0.083
# OVERALL  55.9% 71.6% 45.9% 61.7% 96.3% 137 55 62 20 656 10744 139  313 58.8% 0.090
# -------- EPOCH 10 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.019. Accuracy: 0.999. Recall: 0.998. Precision: 0.986
# Iter 200. Loss: 0.021. Accuracy: 0.999. Recall: 0.998. Precision: 0.988
# Iter 300. Loss: 0.017. Accuracy: 0.999. Recall: 0.997. Precision: 0.991
# Iter 400. Loss: 0.017. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
#
# Tracking: MOT16-02
# Tracks found: 102
# Runtime for MOT16-02: 9.3 s.
# Tracking: MOT16-11
# Tracks found: 90
# Runtime for MOT16-11: 8.4 s.
# Runtime for all sequences: 17.7 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.9% 68.1% 37.0% 52.2% 96.1%  62 11 38 13 390  8873  99  224 49.6% 0.096
# MOT16-11 70.2% 77.4% 64.3% 80.2% 96.6%  75 44 24  7 266  1871  40   90 76.9% 0.083
# OVERALL  56.3% 72.2% 46.2% 61.7% 96.3% 137 55 62 20 656 10744 139  314 58.8% 0.090
# -------- EPOCH 11 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.019. Accuracy: 0.999. Recall: 0.998. Precision: 0.988
# Iter 200. Loss: 0.017. Accuracy: 0.999. Recall: 0.998. Precision: 0.990
# Iter 300. Loss: 0.018. Accuracy: 0.999. Recall: 0.998. Precision: 0.989
# Iter 400. Loss: 0.021. Accuracy: 0.999. Recall: 0.998. Precision: 0.987
#
# Tracking: MOT16-02
# Tracks found: 97
# Runtime for MOT16-02: 9.1 s.
# Tracking: MOT16-11
# Tracks found: 88
# Runtime for MOT16-11: 8.3 s.
# Runtime for all sequences: 17.4 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.3% 67.2% 36.5% 52.2% 96.1%  62 11 38 13 390  8873 100  223 49.6% 0.095
# MOT16-11 70.2% 77.4% 64.3% 80.2% 96.6%  75 44 24  7 266  1871  40   90 76.9% 0.083
# OVERALL  55.9% 71.6% 45.9% 61.7% 96.3% 137 55 62 20 656 10744 140  313 58.8% 0.090
# -------- EPOCH 12 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.015. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Iter 200. Loss: 0.022. Accuracy: 0.999. Recall: 0.998. Precision: 0.988
# Iter 300. Loss: 0.018. Accuracy: 0.999. Recall: 0.998. Precision: 0.990
# Iter 400. Loss: 0.018. Accuracy: 0.999. Recall: 0.999. Precision: 0.987
#
# Tracking: MOT16-02
# Tracks found: 100
# Runtime for MOT16-02: 9.4 s.
# Tracking: MOT16-11
# Tracks found: 88
# Runtime for MOT16-11: 8.3 s.
# Runtime for all sequences: 17.7 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.7% 67.8% 36.8% 52.2% 96.1%  62 11 38 13 390  8873 100  223 49.6% 0.095
# MOT16-11 70.0% 77.2% 64.0% 80.2% 96.6%  75 44 24  7 266  1871  40   90 76.9% 0.083
# OVERALL  56.1% 71.9% 46.0% 61.7% 96.3% 137 55 62 20 656 10744 140  313 58.8% 0.090
# -------- EPOCH 13 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.017. Accuracy: 0.999. Recall: 0.998. Precision: 0.989
# Iter 200. Loss: 0.016. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Iter 300. Loss: 0.016. Accuracy: 0.999. Recall: 0.999. Precision: 0.990
# Iter 400. Loss: 0.022. Accuracy: 0.998. Recall: 0.997. Precision: 0.986
#
# Tracking: MOT16-02
# Tracks found: 97
# Runtime for MOT16-02: 9.4 s.
# Tracking: MOT16-11
# Tracks found: 87
# Runtime for MOT16-11: 8.1 s.
# Runtime for all sequences: 17.5 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.3% 67.2% 36.5% 52.2% 96.1%  62 11 38 13 390  8873 100  223 49.6% 0.095
# MOT16-11 69.4% 76.5% 63.5% 80.2% 96.6%  75 44 24  7 266  1871  40   90 76.9% 0.083
# OVERALL  55.6% 71.2% 45.6% 61.7% 96.3% 137 55 62 20 656 10744 140  313 58.8% 0.090
# -------- EPOCH 14 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.019. Accuracy: 0.999. Recall: 0.998. Precision: 0.988
# Iter 200. Loss: 0.017. Accuracy: 0.999. Recall: 0.998. Precision: 0.989
# Iter 300. Loss: 0.015. Accuracy: 0.999. Recall: 0.999. Precision: 0.992
# Iter 400. Loss: 0.017. Accuracy: 0.999. Recall: 0.999. Precision: 0.988
#
# Tracking: MOT16-02
# Tracks found: 99
# Runtime for MOT16-02: 9.4 s.
# Tracking: MOT16-11
# Tracks found: 87
# Runtime for MOT16-11: 8.1 s.
# Runtime for all sequences: 17.5 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.3% 67.2% 36.5% 52.2% 96.1%  62 11 38 13 390  8873 100  223 49.6% 0.095
# MOT16-11 69.4% 76.5% 63.5% 80.2% 96.6%  75 44 24  7 266  1871  40   90 76.9% 0.083
# OVERALL  55.6% 71.2% 45.6% 61.7% 96.3% 137 55 62 20 656 10744 140  313 58.8% 0.090
# -------- EPOCH 15 --------
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Iter 100. Loss: 0.024. Accuracy: 0.998. Recall: 0.998. Precision: 0.987
# Iter 200. Loss: 0.018. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
# Iter 300. Loss: 0.015. Accuracy: 0.999. Recall: 0.999. Precision: 0.988
# Iter 400. Loss: 0.017. Accuracy: 0.999. Recall: 0.999. Precision: 0.989
#
# Tracking: MOT16-02
# Tracks found: 97
# Runtime for MOT16-02: 9.3 s.
# Tracking: MOT16-11
# Tracks found: 85
# Runtime for MOT16-11: 8.4 s.
# Runtime for all sequences: 17.7 s.
#           IDF1   IDP   IDR  Rcll  Prcn  GT MT PT ML  FP    FN IDs   FM  MOTA  MOTP
# MOT16-02 47.3% 67.2% 36.5% 52.2% 96.1%  62 11 38 13 390  8873  99  223 49.6% 0.095
# MOT16-11 69.5% 76.7% 63.6% 80.2% 96.6%  75 44 24  7 266  1871  39   90 76.9% 0.083
# OVERALL  55.7% 71.3% 45.6% 61.7% 96.3% 137 55 62 20 656 10744 138  313 58.8% 0.090

# %% [markdown]
# # Exercise submission
#
# After executing the following cell the `Colab Notebooks/cv3dst_exercise/output` directory in your Google Drive should contain multiple `MOT16-XY.txt` files.
#
# For the final submission you have to process the test sequences and upload the zipped prediction files to our server. See moodle for a guide how to upload the results.
#
# Note that this time, you only have to evaluate three sequences!

# %%
best_ckpt = torch.load(osp.join(root_dir, 'output', 'best_ckpt.pth'))
assign_net.load_state_dict(best_ckpt)

tracker =  MPNTracker(assign_net=assign_net.eval(), obj_detect=None, patience=MAX_PATIENCE)
test_db = torch.load(osp.join(gnn_root_dir, 'data/preprocessed_data_test_2.pth'))
val_sequences = MOT16Sequences('MOT16-test', osp.join(root_dir, 'data/MOT16'), vis_threshold=0.)
run_tracker(val_sequences, db=test_db, tracker=tracker, output_dir=osp.join(root_dir, 'output'))
# Out:
# Tracking: MOT16-01
# No GT evaluation data available.
# Tracks found: 75
# Runtime for MOT16-01: 35.3 s.
# Writing predictions to: gdrive/My Drive/Colab Notebooks/cv3dst_exercise/output/MOT16-01.txt
# Tracking: MOT16-08
# No GT evaluation data available.
# Tracks found: 129
# Runtime for MOT16-08: 72.4 s.
# Writing predictions to: gdrive/My Drive/Colab Notebooks/cv3dst_exercise/output/MOT16-08.txt
# Tracking: MOT16-12
# No GT evaluation data available.
# Tracks found: 131
# Runtime for MOT16-12: 31.1 s.
# Writing predictions to: gdrive/My Drive/Colab Notebooks/cv3dst_exercise/output/MOT16-12.txt
# Runtime for all sequences: 138.7 s.
